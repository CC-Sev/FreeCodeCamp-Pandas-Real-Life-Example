# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Exercises
# ## Bike store sales

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sales = pd.read_csv(
    'data/sales_data.csv',
    parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Customers_Age`?

# %%
# your code goes here
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %% [markdown]
# Why don't you try with `.mean()`

# %%
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %% [markdown]
# Go ahead and show a <b>density (KDE)</b> and a <b>box plot</b> with the `Customer_Age` data:

# %%
# your code goes here
sales['Customer_Age'].plot(kind='kde', figsize=(4,4))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='box', figsize=(4,4))
# Out:
# <Axes: >

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Order_Quantity`?

# %%
# your code goes here
sales['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %%
sales['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %% [markdown]
# Go ahead and show a <b>histogram</b> and a <b>box plot</b> with the `Order_Quantity` data:

# %%
# your code goes here
sales['Order_Quantity'].plot(kind='hist', bins=30,figsize=(4,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(4,4))
# Out:
# <Axes: >

# %%
sales['Order_Quantity'].plot(kind='hist', bins=30, figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per year do we have?

# %%
# your code goes here
sales['Year'].sum()
# Out:
# 227699915

# %%
sales['Year'].value_counts()
# Out:
# Year
# 2016    29398
# 2014    29398
# 2015    24443
# 2013    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the previous data:

# %%
# your code goes here
sales['Year'].value_counts().plot(kind='pie', figsize=())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # your code goes here
# ----> 2 sales['Year'].value_counts().plot(kind='pie', figsize=())
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(3,3))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per month do we have?

# %%
# your code goes here
sales[['Month', 'Year']].value_counts()
# Out:
# Month     Year
# December  2015    5270
#           2013    5270
# June      2014    5082
#           2016    5082
# May       2014    5015
#                   ...
# November  2012     193
# January   2011     188
#           2012     188
# February  2011     171
#           2012     171
# Name: count, Length: 62, dtype: int64

# %%
sales['Month'].value_counts()

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the previous data:

# %%
# your code goes here
sales['Month'].value_counts().plot(kind='bar', figsize=(3,3))
# Out:
# <Axes: xlabel='Month'>

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which country has the most sales `quantity of sales`?

# %%
# your code goes here
sales['Country'].value_counts()
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %%
sales['Country'].value_counts().head(1)
# Out:
# Country
# United States    39206
# Name: count, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> of the sales per country:

# %%
# your code goes here
sales['Country'].value_counts().plot(kind='bar', figsize=(3,3))
# Out:
# <Axes: xlabel='Country'>

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a list of every product sold

# %%
# your code goes here
#sales['Product'].unique()
sales.loc[:,'Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %%
#sales.loc[:, 'Product'].unique()

sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %% [markdown]
# Create a **bar plot** showing the 10 most sold products (best sellers):

# %%
sales['Product'].value_counts().head(10)
# Out:
# Product
# Water Bottle - 30 oz.      10794
# Patch Kit/8 Patches        10416
# Mountain Tire Tube          6816
# AWC Logo Cap                4358
# Sport-100 Helmet, Red       4220
# Road Tire Tube              4176
# Sport-100 Helmet, Black     4152
# Fender Set - Mountain       4032
# Sport-100 Helmet, Blue      3788
# Touring Tire Tube           3702
# Name: count, dtype: int64

# %%
# your code goes here
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(5,3))
# Out:
# <Axes: xlabel='Product'>

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Unit_Cost` and `Unit_Price`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(3,3))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Order_Quantity` and `Profit`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(3,3))
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %%
sales[['Order_Quantity', 'Profit']].corr()
# Out:
#                 Order_Quantity    Profit
# Order_Quantity        1.000000 -0.238863
# Profit               -0.238863  1.000000

# %%
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Profit` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the profit values.

# %%
# your code goes here
sales[['Profit','Country']].plot(kind='box', by='Country', figsize=(10,6))
# Out:
# Profit    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
prof_per_country = sales.groupby('Country')['Profit'].sum()
prof_per_country.plot(kind='bar', figsize=(10,6))
plt.title('Profit per Country')
plt.xlabel('Country')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# %%
sales[['Profit', 'Country']].boxplot(by='Country', figsize=(10,6))
plt.title('Profit per Country')
plt.xlabel('Country')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.yticks(rotation=-45)
# Out:
# (array([-2000.,     0.,  2000.,  4000.,  6000.,  8000., 10000., 12000.,
#         14000., 16000.]),
#  [Text(0, -2000.0, '−2000'),
#   Text(0, 0.0, '0'),
#   Text(0, 2000.0, '2000'),
#   Text(0, 4000.0, '4000'),
#   Text(0, 6000.0, '6000'),
#   Text(0, 8000.0, '8000'),
#   Text(0, 10000.0, '10000'),
#   Text(0, 12000.0, '12000'),
#   Text(0, 14000.0, '14000'),
#   Text(0, 16000.0, '16000')])

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between the `Customer_Age` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the customer age values.

# %%
# your code goes here
sales[['Customer_Age','Country']].plot(kind='box', by='Country', figsize=(10,6))
#sales[['Customer_Age','Country']].describe()
# Out:
# Customer_Age    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
sales[['Customer_Age', 'Country']].boxplot(by='Country', figsize=(10,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add and calculate a new `Calculated_Date` column
#
# Use `Day`, `Month`, `Year` to create a `Date` column (`YYYY-MM-DD`).

# %%
# your code goes here
sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)
sales['Calculated_Date'].head()
# Out:
# /var/folders/pg/sqf9myss733_86tn8zcr1qtr0000gn/T/ipykernel_80620/387655458.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %%
sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

sales['Calculated_Date'].head()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Parse your `Calculated_Date` column into a datetime object

# %%
# your code goes here
(sales['Calculated_Date'] != sales['Date']).sum()
# Out:
# 0

# %%
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])
sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %%
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])

sales['Calculated_Date'].head()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How did sales evolve through the years?
#
# Show a <b>line plot</b> using `Calculated_Date` column as the x-axis and the count of sales as the y-axis.

# %%
# your code goes here
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))
# Out:
# <Axes: xlabel='Calculated_Date'>

# %%
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))
# Out:
# <Axes: xlabel='Calculated_Date'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Increase 50 U$S revenue to every sale

# %%
# your code goes here
sales['Revenue'] += 50

# %%
sales['Revenue'].head(5)
# Out:
# 0    1000
# 1    1000
# 2    2451
# 3    2138
# 4     468
# Name: Revenue, dtype: int64

# %%
#sales['Revenue'] = sales['Revenue'] + 50

sales['Revenue'] += 50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in `Canada` or `France`?

# %%
# your code goes here
sales.loc[(sales['Country']=='Canada') | (sales['Country']=='France')].shape
# Out:
# (25176, 19)

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')].shape[0]
# Out:
# 25176

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many `Bike Racks` orders were made from Canada?

# %%
# your code goes here
sales.loc[sales['Country']=='Canada'].value_counts()
sales.loc[(sales['Country']=='Canada') & (sales['Sub_Category']=='Bike Racks')].shape
# Out:
# (104, 19)

# %%
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks')].shape[0]
# Out:
# 104

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in each region (state) of France?

# %%
# your code goes here
france_state = sales.loc[(sales['Country'] == 'France'), 'State'].value_counts()
france_state
# Out:
# State
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: count, dtype: int64

# %%
france_states = sales.loc[sales['Country'] == 'France', 'State'].value_counts()

france_states
# Out:
# State
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
france_states.plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='State'>

# %%
france_states.plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales were made per category?

# %%
# your code goes here
sales['Product_Category'].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %%
sales['Product_Category'].value_counts()

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
sales['Product_Category'].value_counts().plot(kind='pie', figsize=(4,4))
# Out:
# <Axes: ylabel='count'>

# %%
sales['Product_Category'].value_counts().plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per accessory sub-categories?

# %%
# your code goes here
accessories = sales.loc[sales['Product_Category']=='Accessories', 'Sub_Category'].value_counts()
accessories
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
accessories = sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()

accessories

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
accessories.plot(kind='bar', figsize=(4,4))
# Out:
# <Axes: xlabel='Sub_Category'>

# %%
accessories.plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per bike sub-categories?

# %%
# your code goes here
bikes = sales.loc[sales['Product_Category']=='Bikes', 'Sub_Category'].value_counts()
bikes
# Out:
# Sub_Category
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: count, dtype: int64

# %%
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()

bikes

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
bikes.plot(kind='pie', figsize=(6,4))
# Out:
# <Axes: ylabel='count'>

# %%
bikes.plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which gender has the most amount of sales?

# %%
# your code goes here
sales['Customer_Gender'].value_counts()
# Out:
# Customer_Gender
# M    58312
# F    54724
# Name: count, dtype: int64

# %%
sales['Customer_Gender'].value_counts()

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Customer_Gender'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales with more than 500 in `Revenue` were made by men?

# %%
# your code goes here
rev_by_men = sales.loc[(sales['Customer_Gender']=='M') & (sales['Revenue']>=500)].shape
rev_by_men
# Out:
# (23392, 19)

# %%
sales.loc[(sales['Customer_Gender'] == 'M') & (sales['Revenue'] == 500)].shape[0]
# Out:
# 50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the top-5 sales with the highest revenue

# %%
# your code goes here
sort_rev = sales['Revenue'].sort_values(ascending=False)
sort_rev.head(5)
# Out:
# 112073    58124
# 112072    54119
# 71129     14362
# 70601     14219
# 59919     14219
# Name: Revenue, dtype: int64

# %%
sales.sort_values(['Revenue'], ascending=False).head(5)
# Out:
#              Date  Day      Month  Year  Customer_Age             Age_Group  \
# 112073 2015-07-24   24       July  2015            52        Adults (35-64)
# 112072 2013-07-24   24       July  2013            52        Adults (35-64)
# 71129  2011-07-08    8       July  2011            22           Youth (<25)
# 70601  2011-09-30   30  September  2011            19           Youth (<25)
# 59919  2011-03-20   20      March  2011            29  Young Adults (25-34)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 70601                F     Canada  British Columbia            Bikes
# 59919                F    Germany            Bayern            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the sale with the highest revenue

# %%
# your code goes here
highest_rev = sales['Revenue'].idxmax()
print(highest_rev)
sales.loc[highest_rev]
# Out:
# 112073
# Date                    2015-07-24 00:00:00
# Day                                      24
# Month                                  July
# Year                                   2015
# Customer_Age                             52
# Age_Group                    Adults (35-64)
# Customer_Gender                           M
# Country                           Australia
# State                            Queensland
# Product_Category                   Clothing
# Sub_Category                          Vests
# Product             Touring-1000 Yellow, 50
# Order_Quantity                           29
# Unit_Cost                              1482
# Unit_Price                             2384
# Profit                                15096
# Cost                                  42978
# Revenue                               58124
# Calculated_Date         2015-07-24 00:00:00
# Name: 112073, dtype: object

# %%
#sales.sort_values(['Revenue'], ascending=False).head(1)

cond = sales['Revenue'] == sales['Revenue'].max()

sales.loc[cond]
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58124      2015-07-24

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with more than 10K in revenue?

# %%
# your code goes here
mean_order_quantity = sales.loc[sales['Revenue']>10_000, 'Order_Quantity'].mean()
mean_order_quantity
# Out:
# 3.689265536723164

# %%
cond = sales['Revenue'] > 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 3.689265536723164

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with less than 10K in revenue?

# %%
# your code goes here
mean_order_quantity = sales.loc[sales['Revenue']<10_000, 'Order_Quantity'].mean()
mean_order_quantity
# Out:
# 11.914539380997528

# %%
cond = sales['Revenue'] < 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 11.914539380997528

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in May of 2016?

# %%
# your code goes here
may_2016 = sales.loc[(sales['Year']==2016) &  (sales['Month']=='May')].shape
may_2016
# Out:
# (5015, 19)

# %%
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May')

sales.loc[cond].shape[0]
# Out:
# 5015

# %%
# Check for null values in rows
rows_with_nulls = sales.isna().any(axis=1)
# Print rows with nulls
print(sales[rows_with_nulls])
# Out:
# Empty DataFrame
# Columns: [Date, Day, Month, Year, Customer_Age, Age_Group, Customer_Gender, Country, State, Product_Category, Sub_Category, Product, Order_Quantity, Unit_Cost, Unit_Price, Profit, Cost, Revenue, Calculated_Date]
# Index: []

# %%
col_with_nulls = sales.isna().any()
print(sales.columns[col_with_nulls])
# Out:
# Index([], dtype='object')

# %%
null_counts_per_col = sales.isna().sum()
print(null_counts_per_col)
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# Calculated_Date     0
# dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made between May and July of 2016?

# %%
# your code goes here
may_to_july_2016 = sales.loc[(sales['Year']==2016) & (sales['Month'].isin(['May','June','July']))].shape
may_to_july_2016
# Out:
# (12164, 19)

# %%
cond = (sales['Year'] == 2016) & (sales['Month'].isin(['May', 'June', 'July']))

sales.loc[cond].shape[0]
# Out:
# 12164

# %% [markdown]
# Show a grouped <b>box plot</b> per month with the profit values.

# %%
# your code goes here
profit_2016 = sales.loc[sales['Year'] == 2016, ['Month', 'Profit']]
profit_2016.boxplot(by='Month', figsize=(12,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Month]'>

# %%
profit_2016 = sales.loc[sales['Year'] == 2016, ['Profit', 'Month']]

profit_2016.boxplot(by='Month', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add 7.2% TAX on every sale `Unit_Price` within United States

# %%
sales.loc[sales['Country']=='United States', 'Unit_Price']
# Out:
# 22        120.0
# 23        120.0
# 34        120.0
# 35        120.0
# 38        120.0
#           ...
# 113021     64.0
# 113022     64.0
# 113023     64.0
# 113024     64.0
# 113025     64.0
# Name: Unit_Price, Length: 39206, dtype: float64

# %%
# your code goes here
sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072

# %%
sales.loc[sales['Country']=='United States', 'Unit_Price']
# Out:
# 22        128.640
# 23        128.640
# 34        128.640
# 35        128.640
# 38        128.640
#            ...
# 113021     68.608
# 113022     68.608
# 113023     68.608
# 113024     68.608
# 113025     68.608
# Name: Unit_Price, Length: 39206, dtype: float64

# %%
#sales.loc[sales['Country'] == 'United States', 'Unit_Price'] = sales.loc[sales['Country'] == 'United States', 'Unit_Price'] * 1.072

sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
